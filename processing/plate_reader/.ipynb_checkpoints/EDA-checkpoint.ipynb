# %%
using CairoMakie, resistance_evolution, CSV, DataFrames, ColorSchemes, Distributions
CairoMakie.activate!()
# Out:
# ┌ Info: Precompiling resistance_evolution [9179e405-7b4d-4191-ac6e-c31ed357b8a4]
# └ @ Base loading.jl:1664

# %%
resistance_evolution.plotting_style.default_makie!()

# %%
color_dict = Dict(["MG1655", "3.19", "IW", "WTlac", "lacUV5"] .=> ColorSchemes.BuPu_5)
rep_dict = Dict([1, 2] .=> [:circle, :xcross])
# Out:
# Dict{Int64, Symbol} with 2 entries:
#   2 => :xcross
#   1 => :circle

# %%
files = [
    "20221229_r1_plate1",
    "20221230_r2_plate1",
    "20230103_r3_plate1",
    "20230104_r1_plate2"
    ]

df = DataFrame()

for file in files
    _df = CSV.read(file * "/exp_analysis_summary.csv", DataFrame)
    insertcols!(_df, 5, :tc => map(x -> parse(Float64, split(x, "_")[1]), _df.pos_selection))
    insertcols!(_df, 5, :rep => map(x -> parse(Int64, split(x, "_")[2]), _df.strain))
    insertcols!(_df, 5, :date => parse(Int64, split(file, "_")[1]))
    _df.strain = map(x -> split(x, "_")[1], _df.strain)
    df = vcat(df, _df)
end
first(df, 5)
# Out:
# 5×8 DataFrame
#  Row │ run      strain     pos_selection  well     date      rep    tc       e ⋯
#      │ String3  SubStrin…  String15       String3  Int64     Int64  Float64  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ r1       MG1655     0.27_µg/ml_tc  A02      20221229      1     0.27    ⋯
#    2 │ r1       MG1655     0.27_µg/ml_tc  A03      20221229      2     0.27
#    3 │ r1       3.19       0.27_µg/ml_tc  A04      20221229      1     0.27
#    4 │ r1       3.19       0.27_µg/ml_tc  A05      20221229      2     0.27
#    5 │ r1       IW         0.27_µg/ml_tc  A06      20221229      1     0.27    ⋯
#                                                                 1 column omitted

# %%
df.strain = map(x -> split(x, "_")[1], df.strain)

fig = Figure(resolution=(600, 300))
ax = Axis(fig[1, 1], xscale=log10)
ax.ylabel = "Relative Growth Rate λ/λ_0"
ax.xlabel = "Tetracycline concentration [µg/ml]"
#ylims!(ax, 0.001, 0.0121)
#vlines!(ax, sort(unique(df.tc)), color="gray", linestyle=:dash, alpha=0.3) 
ax_list = []

for strain in df.strain |> unique
    for run in df[df.strain .== strain, "run"] |> unique
        for rep in [1, 2]
            _df = df[(df.strain .== strain) .& (df.rep .== rep) .& (df.run .== run), :]
            df_λ_0 = combine(groupby(_df[_df.tc .== 0, :], :date), :exp_growth_rate => mean)
            df_comb = combine(groupby(_df[_df.tc .> 0, :], [:tc, :date]), :exp_growth_rate => mean)
            insertcols!(df_comb,  1, :rel_growth_rate => 0.)
            for date in df_λ_0.date |> unique
                df_comb[df_comb.date .== date, :rel_growth_rate] = df_comb[df_comb.date .== date, :exp_growth_rate_mean] ./ 
                df_λ_0[df_λ_0.date .== date, :exp_growth_rate_mean]
            end
            scatter!(
                ax,
                df_comb.tc,
                df_comb[!, :rel_growth_rate],
                strokewidth=0.4,
                strokecolor="black",
                markersize=10,
                color=(color_dict[strain], 1),
                marker=rep_dict[rep]
                )
        end
    end
end

marker_list = [MarkerElement(marker = marker, color = :black,
    strokecolor = :transparent,
    markersize = 8) for marker in [:circle, :xcross]]

color_list = [PolyElement(color = color) for color in ColorSchemes.BuPu_5]

l = Legend(fig,
    [color_list, marker_list],
    [["MG1655", "3.19", "IW", "WTlac", "lacUV5"], string.([1, 2])],
    ["Strain", "Replicate"])

fig[1, 2] = l




save("tc_lambda.pdf", fig)
fig

# %%
cdf = combine(groupby(df, [:strain, :tc]), :exp_growth_rate => ((p) -> (mean_λ=median(p), std_λ=std(p))) => AsTable)


df.strain = map(x -> split(x, "_")[1], df.strain)

fig = Figure(resolution=(600, 300))
ax = Axis(fig[1, 1])#, xscale=log10)
ax.ylabel = "Relative Growth Rate λ/λ_0"
ax.xlabel = "Tetracycline concentration [µg/ml]"
ax_list = []

for strain in cdf.strain |> unique
    _df = cdf[(cdf.strain .== strain), :]
    sort!(_df, "tc")    
    scatter!(
        ax,
        _df.tc,
        _df[!, :mean_λ],
        strokewidth=0.4,
        strokecolor="black",
        markersize=10,
        color=(color_dict[strain], 1),
        )
    lines!(
        ax,
        _df.tc,
        _df[!, :mean_λ],
        color=(color_dict[strain], 1),
        )
    #errorbars!( 
        #ax,
        #_df.tc,
        #_df[!, :mean_λ],
        #_df[!, :std_λ],
        #color=(color_dict[strain], 1),
        #)
end

marker_list = [MarkerElement(marker = marker, color = :black,
    strokecolor = :transparent,
    markersize = 8) for marker in [:circle, :xcross]]

color_list = [PolyElement(color = color) for color in ColorSchemes.BuPu_5]

l = Legend(fig,
    [color_list, marker_list],
    [["MG1655", "3.19", "IW", "WTlac", "lacUV5"], string.([1, 2])],
    ["Strain", "Replicate"])

fig[1, 2] = l

fig

# %%
df.strain = map(x -> split(x, "_")[1], df.strain)

fig = Figure(resolution=(600, 300))
ax = Axis(fig[1, 1], xscale=log10)
ax.ylabel = "Relative Growth Rate λ/λ_0"
ax.xlabel = "Tetracycline concentration [µg/ml]"
#ylims!(ax, 0.001, 0.0121)
#vlines!(ax, sort(unique(df.tc)), color="gray", linestyle=:dash, alpha=0.3) 
ax_list = []

for strain in df.strain |> unique
    for run in df[df.strain .== strain, "run"] |> unique
        for rep in [1, 2]
            _df = df[(df.strain .== strain) .& (df.rep .== rep) .& (df.run .== run), :]
            df_λ_0 = combine(groupby(_df[_df.tc .== 0, :], :date), :exp_growth_rate => mean)
            df_comb = combine(groupby(_df[_df.tc .> 0, :], [:tc, :date]), :exp_growth_rate => mean)
            insertcols!(df_comb,  1, :rel_growth_rate => 0.)
            for date in df_λ_0.date |> unique
                df_comb[df_comb.date .== date, :rel_growth_rate] = df_comb[df_comb.date .== date, :exp_growth_rate_mean] ./ 
                df_λ_0[df_λ_0.date .== date, :exp_growth_rate_mean]
            end
            scatter!(
                ax,
                df_comb.tc,
                df_comb[!, :rel_growth_rate],
                strokewidth=0.4,
                strokecolor="black",
                markersize=10,
                color=(color_dict[strain], 1),
                marker=rep_dict[rep]
                )
        end
    end
end

marker_list = [MarkerElement(marker = marker, color = :black,
    strokecolor = :transparent,
    markersize = 8) for marker in [:circle, :xcross]]

color_list = [PolyElement(color = color) for color in ColorSchemes.BuPu_5]

l = Legend(fig,
    [color_list, marker_list],
    [["MG1655", "3.19", "IW", "WTlac", "lacUV5"], string.([1, 2])],
    ["Strain", "Replicate"])

fig[1, 2] = l




save("tc_lambda.pdf", fig)
fig

# %%
CSV.read("../../data/plate_reader/20220722_r1_allstrains_tc/20220722_r1_allstrains_tc.txt", DataFrame)
# Out:
# 205×98 DataFrame
#  Row │ 0:06:10   37.0       0.038        0.067        0.069        0.062       ⋯
#      │ Time      Float64?   Float64?     Float64?     Float64?     Float64?    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 00:13:10       36.9        0.038        0.067        0.07         0.063 ⋯
#    2 │ 00:20:10       37.0        0.038        0.069        0.071        0.065
#    3 │ 00:27:10       37.0        0.038        0.07         0.072        0.066
#    4 │ 00:34:10       37.0        0.038        0.072        0.074        0.067
#    5 │ 00:41:10       37.1        0.038        0.073        0.076        0.069 ⋯
#    6 │ 00:48:10       37.0        0.038        0.075        0.078        0.071
#    7 │ 00:55:10       37.0        0.038        0.078        0.081        0.072
#    8 │ 01:02:10       37.0        0.038        0.08         0.083        0.075
#    9 │ 01:09:10       37.0        0.038        0.083        0.086        0.077 ⋯
#   10 │ 01:16:10       37.0        0.038        0.086        0.089        0.079
#   11 │ 01:23:10       37.1        0.038        0.088        0.092        0.081
#   ⋮  │    ⋮          ⋮           ⋮            ⋮            ⋮            ⋮      ⋱
#  196 │ 00:00:00  missing    missing      missing      missing      missing
#  197 │ 00:00:00  missing    missing      missing      missing      missing     ⋯
#  198 │ 00:00:00  missing    missing      missing      missing      missing
#  199 │ 00:00:00  missing    missing      missing      missing      missing
#  200 │ 00:00:00  missing    missing      missing      missing      missing
#  201 │ 00:00:00  missing    missing      missing      missing      missing     ⋯
#  202 │ 00:00:00  missing    missing      missing      missing      missing
#  203 │ 00:00:00  missing    missing      missing      missing      missing
#  204 │ 00:00:00  missing    missing      missing      missing      missing
#  205 │ 00:00:00  missing    missing      missing      missing      missing     ⋯
#                                                  92 columns and 184 rows omitted

# %%
df = CSV.read("20220715_r3_allstrains_tc/exp_analysis_summary.csv", DataFrame)
insertcols!(df, 5, :tc => map(x -> parse(Float64, split(x, "_")[1]), df.pos_selection))
fig = Figure(resolution=(500, 300))

insertcols!(df, 5, :rep => map(x -> parse(Int64, split(x, "_")[2]), df.strain))

df.strain = map(x -> split(x, "_")[1], df.strain)

ax = Axis(fig[1, 1])
ax.ylabel = "Growth Rate [1/min]"
ax.xlabel = "Tetracycline concentration [µg/ml]"
ylims!(ax, 0.001, 0.0121)
vlines!(ax, [0, 0.1, 0.16, 0.25], color="gray", linestyle=:dash, alpha=0.3) 
ax_list = []

for strain in df.strain |> unique
    for rep in [1, 2]
        _df = df[(df.strain .== strain) .& (df.rep .== rep), :]
        scatter!(
            ax,
            _df.tc .+ rand(Normal(0, 0.003), length(_df.tc)),
            _df.exp_growth_rate,
            strokewidth=0.4,
            strokecolor="black",
            markersize=8,
            color=(color_dict[strain], 1),
            marker=rep_dict[rep]
            )
    end
end

marker_list = [MarkerElement(marker = marker, color = :black,
    strokecolor = :transparent,
    markersize = 8) for marker in [:circle, :xcross]]

color_list = [PolyElement(color = color) for color in ColorSchemes.BuPu_5]

l = Legend(fig,
    [color_list, marker_list],
    [["MG1655", "3.19", "IW", "WTlac", "lacUV5"], string.([1, 2])],
    ["Strain", "Replicate"])

fig[1, 2] = l




save("tc_lambda_2.pdf", fig)
fig
# Out:
# Figure()
